# %% [markdown]
# # Jupyter Launch Check
# This notebook verifies Jupyter opens in the project folder and executes a simple cell.
#
# **What to do:** Run the code cell below to confirm the kernel executes.

# %%
# Simple test cell
print("Hello, Jupyter!")
